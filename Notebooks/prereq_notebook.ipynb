# %%
print ("Hello class!")

# %% [markdown]
# My name is Christina Patton. I am a single mother with three kids. I hope to use these classes to break into an industry that i love and will help me provide a better life for my kids. Honestly the whole concept excites me I have always loved mystery novels and data science and its uses remind me of trying to solve a mystry about data.
